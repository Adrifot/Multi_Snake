# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stats.csv")

# %%
df.plot(x="generation", y=["avg_fitness", "max_fitness", "min_fitness", "median_fitness"])
plt.show()

# %%
df.plot(x="generation", y=["unique_chromosomes", "num_snakes"])
plt.show()

# %%
df.plot(x="generation", y=["avg_energy"])
plt.show()
